# %%
from ultralytics import YOLO

# %%
model= YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 16.6MB/s]

# %%
# !yolo task=detect mode=train model=yolov8n.pt imgsz=640 data=config.yaml epochs=30 batch=8 amp=False
# Out:
# New https://pypi.org/project/ultralytics/8.2.36 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.35 🚀 Python-3.8.10 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce MX450, 2048MiB)
# ...

# %%
# !yolo task=detect mode=val model="C:\Users\aman bhardwaj\Desktop\AMAN_YOLO\runs\detect\train\weights\best.pt" imgsz=640 data=config.yaml epochs=5 batch=8 amp=False
# Out:
# Ultralytics YOLOv8.2.35 🚀 Python-3.8.10 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce MX450, 2048MiB)
# Model summary (fused): 168 layers, 3007013 parameters, 0 gradients, 8.1 GFLOPs
#                    all         13         15      0.912      0.888      0.976      0.831
#                   ball          2          2      0.939          1      0.995       0.92
#              bookshelf          2          2      0.945          1      0.995      0.945
#                   lamp          3          3          1      0.547      0.995      0.588
#                  plant          3          3      0.647      0.667      0.863      0.777
#                   shoe          2          2      0.948          1      0.995      0.995
#                   suit          1          1      0.926          1      0.995      0.697
#              telephone          2          2      0.977          1      0.995      0.895
# Speed: 0.7ms preprocess, 18.3ms inference, 0.0ms loss, 1.9ms postprocess per image
# ...

# %%
# !yolo task=detect mode=predict model="C:\Users\aman bhardwaj\Desktop\AMAN_YOLO\runs\detect\train\weights\best.pt" conf=0.25 source="AIR_2.png"
# Out:
# Ultralytics YOLOv8.2.35 🚀 Python-3.8.10 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce MX450, 2048MiB)
# Model summary (fused): 168 layers, 3007013 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 c:\Users\aman bhardwaj\Desktop\aman_yolo\AIR_2.png: 384x640 1 ball, 2 lamps, 2 plants, 2 telephones, 43.5ms
# Speed: 0.0ms preprocess, 43.5ms inference, 10.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs\detect\predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
